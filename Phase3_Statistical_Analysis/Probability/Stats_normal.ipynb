# %%
classes , methods , (#####pip) -- library (a particular operation)

# %%
import numpy as np  ### (alias)
import seaborn as sns ### (alias)

# %%
##l=[1,2,2,2,4,5,6,8,9,3]

# %%
##len(l)

# %%
# sum=0
# for i in l:
#     sum+=i
# print(sum)
# print("mean",sum/len(l))

# %%
#np.mean(l)

# %%
## variance = (standard deviation)^2 (sigma)^2 ###root(variance)

# %%
mu=0.5  ###(mean)
sigma=0.1  ### (standard deviation)

# %%
s=np.random.normal(mu,sigma,1000) ### take 1000 data points of mean and sd 
s
# Out:
# array([0.38133229, 0.47014921, 0.44252699, 0.41896762, 0.42195002,
#        0.53290598, 0.47347454, 0.33920459, 0.54574022, 0.5667476 ,
#        0.44265135, 0.49125307, 0.3164824 , 0.57496087, 0.397709  ,
#        0.51622955, 0.36068606, 0.71372732, 0.68064426, 0.28843694,
#        0.58107606, 0.47939795, 0.39787536, 0.50704027, 0.61236168,
#        0.55696719, 0.6222544 , 0.51003754, 0.44892286, 0.42875744,
#        0.64425318, 0.53155066, 0.37678255, 0.56785676, 0.63961382,
#        0.48552062, 0.592656  , 0.52044213, 0.43241352, 0.36421814,
#        0.61064478, 0.70850587, 0.5703324 , 0.50898794, 0.41263252,
#        0.32065851, 0.54647242, 0.52737166, 0.60340496, 0.59662808,
#        0.48580118, 0.49209394, 0.58076955, 0.33730231, 0.57878884,
#        0.43760389, 0.41945611, 0.64315671, 0.54558698, 0.38329884,
#        0.45883063, 0.5336335 , 0.65568212, 0.35907572, 0.53150125,
#        0.50340847, 0.5588841 , 0.45311487, 0.32057297, 0.49822602,
# ...

# %%
len(s)
# Out:
# 1000

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
sns.distplot(s)
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
### mean = 0 and standard deviation =1
