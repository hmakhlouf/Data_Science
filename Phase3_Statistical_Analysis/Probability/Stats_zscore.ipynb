# %%
import pandas as pd

# %%
df=pd.read_csv('../Datasets/blood_pressure.csv')
df
# Out:
#      Unnamed: 0  patient     sex agegrp  bp_before  bp_after
# 0             0        1    Male  30-45        143       153
# 1             1        2    Male  30-45        163       170
# 2             2        3    Male  30-45        153       168
# 3             3        4    Male  30-45        153       142
# 4             4        5    Male  30-45        146       141
# ..          ...      ...     ...    ...        ...       ...
# 115         115      116  Female    60+        152       152
# 116         116      117  Female    60+        161       152
# 117         117      118  Female    60+        165       174
# 118         118      119  Female    60+        149       151
# 119         119      120  Female    60+        185       163
#
# [120 rows x 6 columns]

# %%
#1000 : 10$ , 1001: 100$ , 50$ , 80$ , 0.001$ (Scale data --- argument ) = z-score

# %%
### mean = median #(relation - skewness ) # Kurtosis

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df.plot.box()
# Out:
# <AxesSubplot:>

# %%
df.describe() ### 50% - median, mean (skewness )
# Out:
#        Unnamed: 0     patient   bp_before    bp_after
# count  120.000000  120.000000  120.000000  120.000000
# mean    59.500000   60.500000  156.450000  151.358333
# std     34.785054   34.785054   11.389845   14.177622
# min      0.000000    1.000000  138.000000  125.000000
# 25%     29.750000   30.750000  147.000000  140.750000
# 50%     59.500000   60.500000  154.500000  149.500000
# 75%     89.250000   90.250000  164.000000  161.000000
# max    119.000000  120.000000  185.000000  185.000000

# %%
#z = (value - mean) / standard_deviation

# %%
#z = #x(143) - mean (156.45) / (11.38)(standard deviation )

# %%
from sklearn.preprocessing import StandardScaler ## Normalization (Normal distribtion) -- CLT 
scaling=StandardScaler()

# %%
scaling.fit_transform(df[['bp_before','bp_after']])
# Out:
# array([[-1.18582775,  0.11627831],
#        [ 0.57748489,  1.32037861],
#        [-0.30417143,  1.17871975],
#        [-0.30417143, -0.66284541],
#        [-0.92133085, -0.73367484],
#        [-0.56866833, -0.30869826],
#        [-0.74499959, -1.30031027],
#        [-0.30417143, -0.73367484],
#        [-0.30417143, -1.44196913],
#        [ 0.13665673, -1.86694571],
#        [-0.65683396,  0.89540203],
#        [ 1.45914121,  0.54125489],
#        [ 0.75381615, -1.15865141],
#        [-1.00949649,  0.54125489],
#        [-1.18582775,  0.11627831],
#        [-0.39233706, -1.79611628],
#        [-1.36215901,  0.75374318],
#        [ 1.7236381 , -1.22948084],
#        [-1.18582775, -1.08782198],
#        [ 0.48931926, -0.09620997],
#        [-0.65683396,  1.17871975],
#        [-0.03967453,  0.25793717],
#        [-0.48050269, -1.08782198],
#        [ 0.22482236, -1.3711397 ],
#        [ 0.66565052,  0.61208432],
#        [-0.2160058 ,  0.61208432],
#        [-0.39233706, -1.08782198],
# ...

# %%
#fit : calculate the statistical data parameters (mean, standard deviation ) -- logic 
#transform: applying this calculated parameters on the data  -- application
